# %% [markdown]
# # Ejercicio 1: Introducción a Recuperación de Información
#
# ## Objetivo de la práctica
# - Entender el problema de **buscar información** en colecciones de texto.
# - Comprender por qué se necesita un **índice invertido** en recuperación de información.
# - Programar una primera solución manual y luego optimizarla con un índice.
# - Evaluar la mejora en tiempos de búsqueda cuando usamos estructuras adecuadas.

# %% [markdown]
# ## Parte 1: Búsqueda lineal en documentos
#
# ### Actividad
# 1. Se te proporcionará un conjunto de documentos de texto.
# 2. Escribe una función que:
#    - Lea todos los documentos.
#    - Busque una palabra ingresada por el usuario.
#    - Muestre en qué documentos aparece la palabra.

# %%
import time

nombre_archivo = "01_corpus_turismo.txt"
palabra_buscar = "Quito"

def find(palabra_buscar):
    inicio = time.time()

    try:
        with open(nombre_archivo, "r", encoding="utf-8") as archivo:
            lineas = archivo.readlines()

        resultados = []  # Para guardar en qué documentos está
        conteo_total = 0  # Para contar el total de veces que aparece la palabra

        for numero_linea, linea in enumerate(lineas, start=1):
            apariciones_linea = linea.count(palabra_buscar)
            if apariciones_linea > 0:
                resultados.append(numero_linea)  # Solo guardamos el número de documento
                conteo_total += apariciones_linea  # Sumar todas las apariciones

        fin = time.time()
        tiempo = fin - inicio

        return {
            "documentos_encontrados": resultados,  # Solo número de documentos
            "total_apariciones": conteo_total,      # Total de veces que apareció la palabra
            "tiempo_segundos": tiempo               # Tiempo que tardó en buscar
        }

    except FileNotFoundError:
        print(f"El archivo '{nombre_archivo}' no fue encontrado.")
        return {
            "documentos_encontrados": [],
            "total_apariciones": 0,
            "tiempo_segundos": 0
        }

# Llamar a la función
resultado = find(palabra_buscar)

# Mostrar resultados
print(f"Documentos donde aparece '{palabra_buscar}': {resultado['documentos_encontrados']}")
print(f"Total de veces que aparece: {resultado['total_apariciones']}")
print(f"Tiempo de búsqueda: {resultado['tiempo_segundos']:.6f} segundos")
# Out:
# Documentos donde aparece 'Quito': [3]
# Total de veces que aparece: 1
# Tiempo de búsqueda: 0.000537 segundos

# %% [markdown]
# ## Parte 2: Construcción de un índice invertido
#
# ### Actividad
# 1. Escribe un programa que:
#    - Recorra todos los documentos.
#    - Construya un **índice invertido**, es decir, un diccionario donde:
#      - Cada palabra clave apunta a una lista de documentos donde aparece.
#
# 2. Escribe una nueva función de búsqueda que:
#    - Consulte directamente el índice para encontrar los documentos relevantes.
#    - Sea mucho más rápida que la búsqueda lineal.

# %%
def construir_e_imprimir_indice(nombre_archivo):
    try:
        with open(nombre_archivo, "r", encoding="utf-8") as archivo:
            lineas = archivo.readlines()

        # Set de palabras únicas
        palabras_unicas = set()

        for linea in lineas:
            palabras = linea.strip().split()
            palabras_unicas.update(palabras)

        # Construir el índice invertido
        indice_invertido = {palabra: [] for palabra in palabras_unicas}

        for numero_linea, linea in enumerate(lineas, start=1):
            palabras_linea = linea.strip().split()
            for palabra in palabras_linea:
                if palabra in indice_invertido:
                    indice_invertido[palabra].append(numero_linea)

        # 🔵 Imprimir palabra y documentos donde aparece
        print("Índice Invertido completo:")
        for palabra in sorted(indice_invertido.keys()):
            documentos = indice_invertido[palabra]
            print(f"Palabra: '{palabra}' aparece en los dicumentos: {documentos}")

        return indice_invertido

    except FileNotFoundError:
        print(f"El archivo '{nombre_archivo}' no fue encontrado.")
        return {}
import time

def buscar_palabra_en_indice(indice_invertido, palabra_buscar):
    inicio = time.time()

    documentos = indice_invertido.get(palabra_buscar, [])

    fin = time.time()
    tiempo = fin - inicio

    return {
        "documentos_encontrados": documentos,
        "cantidad_documentos": len(documentos),
        "tiempo_segundos": tiempo
    }
# Construir el índice invertido y mostrarlo
indice_invertido = construir_e_imprimir_indice(nombre_archivo)

# Ahora buscar una palabra usando la función
palabra_buscar = "Quito"
resultado = buscar_palabra_en_indice(indice_invertido, palabra_buscar)

print(f"\nResultados de búsqueda para '{palabra_buscar}':")
print(f"Documentos encontrados: {resultado['documentos_encontrados']}")
print(f"Cantidad de documentos: {resultado['cantidad_documentos']}")
print(f"Tiempo de búsqueda: {resultado['tiempo_segundos']:.10f} segundos")
# Out:
# Índice Invertido completo:
# Palabra: '2000,' aparece en los dicumentos: [10]
# Palabra: 'Agua' aparece en los dicumentos: [4]
# Palabra: 'Amazonía' aparece en los dicumentos: [12]
# Palabra: 'Andes.' aparece en los dicumentos: [8]
# Palabra: 'Baños' aparece en los dicumentos: [4]
# Palabra: 'Cajas' aparece en los dicumentos: [13]
# Palabra: 'Cotopaxi' aparece en los dicumentos: [8]
# Palabra: 'Cuenca' aparece en los dicumentos: [7]
# Palabra: 'Ecuador' aparece en los dicumentos: [1]
# Palabra: 'El' aparece en los dicumentos: [8, 13]
# Palabra: 'En' aparece en los dicumentos: [4, 12]
# Palabra: 'Galápagos' aparece en los dicumentos: [2]
# Palabra: 'Guayaquil' aparece en los dicumentos: [10]
# Palabra: 'Humanidad' aparece en los dicumentos: [3]
# Palabra: 'Islas' aparece en los dicumentos: [2]
# Palabra: 'La' aparece en los dicumentos: [3, 5, 11]
# Palabra: 'Laguna' aparece en los dicumentos: [11]
# Palabra: 'Las' aparece en los dicumentos: [2]
# Palabra: 'Longevidad,' aparece en los dicumentos: [15]
# Palabra: 'Los' aparece en los dicumentos: [14]
# Palabra: 'López.' aparece en los dicumentos: [5]
# Palabra: 'Malecón' aparece en los dicumentos: [10]
# Palabra: 'Mindo' aparece en los dicumentos: [9]
# Palabra: 'Montañita' aparece en los dicumentos: [16]
# Palabra: 'Montañita,' aparece en los dicumentos: [5]
# Palabra: 'Nacional' aparece en los dicumentos: [13]
# Palabra: 'Otavalo' aparece en los dicumentos: [6]
# Palabra: 'Pacífico.' aparece en los dicumentos: [10]
# Palabra: 'Parque' aparece en los dicumentos: [13]
# Palabra: 'Patrimonio' aparece en los dicumentos: [3]
# Palabra: 'Puerto' aparece en los dicumentos: [5]
# Palabra: 'Quilotoa' aparece en los dicumentos: [11]
# Palabra: 'Quito' aparece en los dicumentos: [3]
# Palabra: 'Ruta' aparece en los dicumentos: [5]
# Palabra: 'Salinas' aparece en los dicumentos: [5]
# Palabra: 'Santa,' aparece en los dicumentos: [4]
# Palabra: 'Spondylus' aparece en los dicumentos: [5]
# Palabra: 'UNESCO.' aparece en los dicumentos: [3]
# Palabra: 'Valle' aparece en los dicumentos: [15]
# Palabra: 'Vilcabamba,' aparece en los dicumentos: [15]
# Palabra: 'a' aparece en los dicumentos: [7, 8, 10, 13, 13, 13]
# Palabra: 'alrededor' aparece en los dicumentos: [11]
# Palabra: 'altitud.' aparece en los dicumentos: [13]
# Palabra: 'arquitectura' aparece en los dicumentos: [7]
# Palabra: 'artesanal.' aparece en los dicumentos: [6]
# Palabra: 'ascensiones' aparece en los dicumentos: [8]
# Palabra: 'atrae' aparece en los dicumentos: [15]
# Palabra: 'atraen' aparece en los dicumentos: [2]
# Palabra: 'aventura' aparece en los dicumentos: [4]
# Palabra: 'aves' aparece en los dicumentos: [9]
# Palabra: 'avistamiento' aparece en los dicumentos: [9]
# Palabra: 'bienestar' aparece en los dicumentos: [15]
# Palabra: 'biodiversidad' aparece en los dicumentos: [2]
# Palabra: 'bosques' aparece en los dicumentos: [9]
# Palabra: 'cada' aparece en los dicumentos: [14]
# Palabra: 'caminatas' aparece en los dicumentos: [13]
# Palabra: 'canopy.' aparece en los dicumentos: [4]
# Palabra: 'cascadas.' aparece en los dicumentos: [12]
# Palabra: 'centro' aparece en los dicumentos: [3]
# Palabra: 'cercanía' aparece en los dicumentos: [10]
# Palabra: 'ciudad' aparece en los dicumentos: [3]
# Palabra: 'colonial' aparece en los dicumentos: [7]
# Palabra: 'color' aparece en los dicumentos: [11]
# Palabra: 'como' aparece en los dicumentos: [4, 5, 15]
# Palabra: 'comunidades' aparece en los dicumentos: [12]
# Palabra: 'con' aparece en los dicumentos: [1, 3, 7, 10, 11]
# Palabra: 'conecta' aparece en los dicumentos: [5]
# Palabra: 'conocer' aparece en los dicumentos: [12]
# Palabra: 'conocido' aparece en los dicumentos: [15]
# Palabra: 'cráter.' aparece en los dicumentos: [11]
# Palabra: 'cuenta' aparece en los dicumentos: [3]
# Palabra: 'cultura' aparece en los dicumentos: [6]
# Palabra: 'de' aparece en los dicumentos: [2, 3, 3, 4, 4, 4, 8, 8, 9, 9, 11, 14, 14, 14, 15, 16]
# Palabra: 'declarado' aparece en los dicumentos: [3]
# Palabra: 'del' aparece en los dicumentos: [5, 10, 11]
# Palabra: 'deportes' aparece en los dicumentos: [4]
# Palabra: 'deslumbra' aparece en los dicumentos: [7]
# Palabra: 'disfrutan' aparece en los dicumentos: [4, 14]
# Palabra: 'durante' aparece en los dicumentos: [16]
# Palabra: 'ecológico.' aparece en los dicumentos: [1]
# Palabra: 'ecuatorianos' aparece en los dicumentos: [12]
# Palabra: 'el' aparece en los dicumentos: [1, 2, 9, 12, 14, 15, 15]
# Palabra: 'en' aparece en los dicumentos: [14, 15]
# Palabra: 'entre' aparece en los dicumentos: [13]
# Palabra: 'es' aparece en los dicumentos: [1, 6, 9]
# Palabra: 'excursionistas' aparece en los dicumentos: [8]
# Palabra: 'exploración' aparece en los dicumentos: [9]
# Palabra: 'famosas' aparece en los dicumentos: [5]
# Palabra: 'famoso' aparece en los dicumentos: [6]
# Palabra: 'feriado' aparece en los dicumentos: [14]
# Palabra: 'feriado,' aparece en los dicumentos: [12]
# Palabra: 'feriados' aparece en los dicumentos: [16]
# Palabra: 'fiestas' aparece en los dicumentos: [14]
# Palabra: 'gastronomía' aparece en los dicumentos: [7, 14]
# Palabra: 'gran' aparece en los dicumentos: [13]
# Palabra: 'histórico' aparece en los dicumentos: [3]
# Palabra: 'ideales' aparece en los dicumentos: [1]
# Palabra: 'impacta' aparece en los dicumentos: [11]
# Palabra: 'impresionantes' aparece en los dicumentos: [8]
# Palabra: 'indígena' aparece en los dicumentos: [6]
# Palabra: 'indígenas' aparece en los dicumentos: [12]
# Palabra: 'interesados' aparece en los dicumentos: [15]
# Palabra: 'invita' aparece en los dicumentos: [13]
# Palabra: 'jóvenes' aparece en los dicumentos: [16]
# Palabra: 'la' aparece en los dicumentos: [3, 3, 9, 12, 14, 15, 15]
# Palabra: 'lagunas' aparece en los dicumentos: [13]
# Palabra: 'las' aparece en los dicumentos: [8, 10, 14]
# Palabra: 'llena' aparece en los dicumentos: [16]
# Palabra: 'locales' aparece en los dicumentos: [14]
# Palabra: 'los' aparece en los dicumentos: [4, 7, 8, 8, 13, 16]
# Palabra: 'megadiverso,' aparece en los dicumentos: [1]
# Palabra: 'mercado' aparece en los dicumentos: [6]
# Palabra: 'montañas' aparece en los dicumentos: [1]
# Palabra: 'muchos' aparece en los dicumentos: [12]
# Palabra: 'mundo' aparece en los dicumentos: [2]
# Palabra: 'más' aparece en los dicumentos: [8]
# Palabra: 'nacionales.' aparece en los dicumentos: [16]
# Palabra: 'naturaleza.' aparece en los dicumentos: [15]
# Palabra: 'nocturna' aparece en los dicumentos: [10]
# Palabra: 'nublados.' aparece en los dicumentos: [9]
# Palabra: 'ofrece' aparece en los dicumentos: [8]
# Palabra: 'para' aparece en los dicumentos: [1, 9, 12]
# Palabra: 'paraíso' aparece en los dicumentos: [9]
# Palabra: 'país' aparece en los dicumentos: [1]
# Palabra: 'playas' aparece en los dicumentos: [5, 10]
# Palabra: 'playas,' aparece en los dicumentos: [1]
# Palabra: 'por' aparece en los dicumentos: [2, 3, 6]
# Palabra: 'páramos' aparece en los dicumentos: [13]
# Palabra: 'rafting' aparece en los dicumentos: [4]
# Palabra: 'región.' aparece en los dicumentos: [14]
# Palabra: 'se' aparece en los dicumentos: [16]
# Palabra: 'selvas' aparece en los dicumentos: [1]
# Palabra: 'senderos' aparece en los dicumentos: [11]
# Palabra: 'sorprende' aparece en los dicumentos: [10]
# Palabra: 'su' aparece en los dicumentos: [2, 6, 6, 7, 7, 10, 10, 10, 11]
# Palabra: 'surfistas' aparece en los dicumentos: [16]
# Palabra: 'todo' aparece en los dicumentos: [2]
# Palabra: 'tradicional.' aparece en los dicumentos: [7]
# Palabra: 'trekking' aparece en los dicumentos: [11]
# Palabra: 'turismo' aparece en los dicumentos: [1]
# Palabra: 'turistas' aparece en los dicumentos: [4, 7, 13, 14]
# Palabra: 'turquesa' aparece en los dicumentos: [11]
# Palabra: 'típica' aparece en los dicumentos: [14]
# Palabra: 'un' aparece en los dicumentos: [1, 3, 9]
# Palabra: 'una' aparece en los dicumentos: [8]
# Palabra: 'viajeros' aparece en los dicumentos: [16]
# Palabra: 'vibrante' aparece en los dicumentos: [6]
# Palabra: 'vida' aparece en los dicumentos: [10]
# Palabra: 'visitan' aparece en los dicumentos: [12]
# Palabra: 'visitantes' aparece en los dicumentos: [2, 15]
# Palabra: 'volcán' aparece en los dicumentos: [8]
# Palabra: 'y' aparece en los dicumentos: [1, 4, 5, 6, 7, 9, 10, 11, 12, 13, 14, 15, 16]
# Palabra: 'única.' aparece en los dicumentos: [2]
#
# Resultados de búsqueda para 'Quito':
# Documentos encontrados: [3]
# Cantidad de documentos: 1
# Tiempo de búsqueda: 0.0000028610 segundos

# %% [markdown]
# ## Parte 3: Evaluación de tiempos de búsqueda
# ### Actividad
#
# 1. Realiza la búsqueda de varias palabras usando:
#       -  Corpus pequeño: 16 documentos (turismo en Ecuador).
#       -  Corpus grande: 500 documentos (versión ampliada).
# 2. Mide el tiempo de ejecución:
#       -  Para búsqueda lineal.
#       -  Para búsqueda usando índice invertido.
#       -  Grafica o presenta los resultados en una tabla comparativa.
#
# ### Ejemplo de palabras para buscar
# - quito
# - montañita
# - feriado
# - playas
# - aventura
# - galápagos

# %%
# Preparar datos
nombre_archivo = "01_corpus_turismo.txt"
palabras_a_buscar = ["quito", "montañita", "feriado", "playas", "aventura", "galápagos"]

# Construir el índice invertido una sola vez
indice_invertido = construir_e_imprimir_indice(nombre_archivo)

# Guardar resultados
resultados = []

for palabra in palabras_a_buscar:
    # Búsqueda lineal
    resultado_lineal = find(palabra)
    
    # Búsqueda con índice invertido
    resultado_indice = buscar_palabra_en_indice(indice_invertido, palabra)
    
    # Guardar resultados para la tabla
    resultados.append({
        "palabra": palabra,
        "tiempo_lineal": resultado_lineal['tiempo_segundos'],
        "tiempo_indice": resultado_indice['tiempo_segundos'],
        "docs_lineal": resultado_lineal['total_apariciones'],  # en find() es 'total_apariciones'
        "docs_indice": resultado_indice['cantidad_documentos'] # en índice es 'cantidad_documentos'
    })

# Imprimir resultados
print("\nTabla comparativa de tiempos:")
print(f"{'Palabra':<15} {'T. Lineal (s)':<15} {'T. Índice (s)':<15} {'Apariciones Lineal':<20} {'Docs Índice'}")
print("-" * 80)
for res in resultados:
    print(f"{res['palabra']:<15} {res['tiempo_lineal']:<15.10f} {res['tiempo_indice']:<15.10f} {res['docs_lineal']:<20} {res['docs_indice']}")
# Out:
# Índice Invertido completo:
# Palabra: '2000,' aparece en los dicumentos: [10]
# Palabra: 'Agua' aparece en los dicumentos: [4]
# Palabra: 'Amazonía' aparece en los dicumentos: [12]
# Palabra: 'Andes.' aparece en los dicumentos: [8]
# Palabra: 'Baños' aparece en los dicumentos: [4]
# Palabra: 'Cajas' aparece en los dicumentos: [13]
# Palabra: 'Cotopaxi' aparece en los dicumentos: [8]
# Palabra: 'Cuenca' aparece en los dicumentos: [7]
# Palabra: 'Ecuador' aparece en los dicumentos: [1]
# Palabra: 'El' aparece en los dicumentos: [8, 13]
# Palabra: 'En' aparece en los dicumentos: [4, 12]
# Palabra: 'Galápagos' aparece en los dicumentos: [2]
# Palabra: 'Guayaquil' aparece en los dicumentos: [10]
# Palabra: 'Humanidad' aparece en los dicumentos: [3]
# Palabra: 'Islas' aparece en los dicumentos: [2]
# Palabra: 'La' aparece en los dicumentos: [3, 5, 11]
# Palabra: 'Laguna' aparece en los dicumentos: [11]
# Palabra: 'Las' aparece en los dicumentos: [2]
# Palabra: 'Longevidad,' aparece en los dicumentos: [15]
# Palabra: 'Los' aparece en los dicumentos: [14]
# Palabra: 'López.' aparece en los dicumentos: [5]
# Palabra: 'Malecón' aparece en los dicumentos: [10]
# Palabra: 'Mindo' aparece en los dicumentos: [9]
# Palabra: 'Montañita' aparece en los dicumentos: [16]
# Palabra: 'Montañita,' aparece en los dicumentos: [5]
# Palabra: 'Nacional' aparece en los dicumentos: [13]
# Palabra: 'Otavalo' aparece en los dicumentos: [6]
# Palabra: 'Pacífico.' aparece en los dicumentos: [10]
# Palabra: 'Parque' aparece en los dicumentos: [13]
# Palabra: 'Patrimonio' aparece en los dicumentos: [3]
# Palabra: 'Puerto' aparece en los dicumentos: [5]
# Palabra: 'Quilotoa' aparece en los dicumentos: [11]
# Palabra: 'Quito' aparece en los dicumentos: [3]
# Palabra: 'Ruta' aparece en los dicumentos: [5]
# Palabra: 'Salinas' aparece en los dicumentos: [5]
# Palabra: 'Santa,' aparece en los dicumentos: [4]
# Palabra: 'Spondylus' aparece en los dicumentos: [5]
# Palabra: 'UNESCO.' aparece en los dicumentos: [3]
# Palabra: 'Valle' aparece en los dicumentos: [15]
# Palabra: 'Vilcabamba,' aparece en los dicumentos: [15]
# Palabra: 'a' aparece en los dicumentos: [7, 8, 10, 13, 13, 13]
# Palabra: 'alrededor' aparece en los dicumentos: [11]
# Palabra: 'altitud.' aparece en los dicumentos: [13]
# Palabra: 'arquitectura' aparece en los dicumentos: [7]
# Palabra: 'artesanal.' aparece en los dicumentos: [6]
# Palabra: 'ascensiones' aparece en los dicumentos: [8]
# Palabra: 'atrae' aparece en los dicumentos: [15]
# Palabra: 'atraen' aparece en los dicumentos: [2]
# Palabra: 'aventura' aparece en los dicumentos: [4]
# Palabra: 'aves' aparece en los dicumentos: [9]
# Palabra: 'avistamiento' aparece en los dicumentos: [9]
# Palabra: 'bienestar' aparece en los dicumentos: [15]
# Palabra: 'biodiversidad' aparece en los dicumentos: [2]
# Palabra: 'bosques' aparece en los dicumentos: [9]
# Palabra: 'cada' aparece en los dicumentos: [14]
# Palabra: 'caminatas' aparece en los dicumentos: [13]
# Palabra: 'canopy.' aparece en los dicumentos: [4]
# Palabra: 'cascadas.' aparece en los dicumentos: [12]
# Palabra: 'centro' aparece en los dicumentos: [3]
# Palabra: 'cercanía' aparece en los dicumentos: [10]
# Palabra: 'ciudad' aparece en los dicumentos: [3]
# Palabra: 'colonial' aparece en los dicumentos: [7]
# Palabra: 'color' aparece en los dicumentos: [11]
# Palabra: 'como' aparece en los dicumentos: [4, 5, 15]
# Palabra: 'comunidades' aparece en los dicumentos: [12]
# Palabra: 'con' aparece en los dicumentos: [1, 3, 7, 10, 11]
# Palabra: 'conecta' aparece en los dicumentos: [5]
# Palabra: 'conocer' aparece en los dicumentos: [12]
# Palabra: 'conocido' aparece en los dicumentos: [15]
# Palabra: 'cráter.' aparece en los dicumentos: [11]
# Palabra: 'cuenta' aparece en los dicumentos: [3]
# Palabra: 'cultura' aparece en los dicumentos: [6]
# Palabra: 'de' aparece en los dicumentos: [2, 3, 3, 4, 4, 4, 8, 8, 9, 9, 11, 14, 14, 14, 15, 16]
# Palabra: 'declarado' aparece en los dicumentos: [3]
# Palabra: 'del' aparece en los dicumentos: [5, 10, 11]
# Palabra: 'deportes' aparece en los dicumentos: [4]
# Palabra: 'deslumbra' aparece en los dicumentos: [7]
# Palabra: 'disfrutan' aparece en los dicumentos: [4, 14]
# Palabra: 'durante' aparece en los dicumentos: [16]
# Palabra: 'ecológico.' aparece en los dicumentos: [1]
# Palabra: 'ecuatorianos' aparece en los dicumentos: [12]
# Palabra: 'el' aparece en los dicumentos: [1, 2, 9, 12, 14, 15, 15]
# Palabra: 'en' aparece en los dicumentos: [14, 15]
# Palabra: 'entre' aparece en los dicumentos: [13]
# Palabra: 'es' aparece en los dicumentos: [1, 6, 9]
# Palabra: 'excursionistas' aparece en los dicumentos: [8]
# Palabra: 'exploración' aparece en los dicumentos: [9]
# Palabra: 'famosas' aparece en los dicumentos: [5]
# Palabra: 'famoso' aparece en los dicumentos: [6]
# Palabra: 'feriado' aparece en los dicumentos: [14]
# Palabra: 'feriado,' aparece en los dicumentos: [12]
# Palabra: 'feriados' aparece en los dicumentos: [16]
# Palabra: 'fiestas' aparece en los dicumentos: [14]
# Palabra: 'gastronomía' aparece en los dicumentos: [7, 14]
# Palabra: 'gran' aparece en los dicumentos: [13]
# Palabra: 'histórico' aparece en los dicumentos: [3]
# Palabra: 'ideales' aparece en los dicumentos: [1]
# Palabra: 'impacta' aparece en los dicumentos: [11]
# Palabra: 'impresionantes' aparece en los dicumentos: [8]
# Palabra: 'indígena' aparece en los dicumentos: [6]
# Palabra: 'indígenas' aparece en los dicumentos: [12]
# Palabra: 'interesados' aparece en los dicumentos: [15]
# Palabra: 'invita' aparece en los dicumentos: [13]
# Palabra: 'jóvenes' aparece en los dicumentos: [16]
# Palabra: 'la' aparece en los dicumentos: [3, 3, 9, 12, 14, 15, 15]
# Palabra: 'lagunas' aparece en los dicumentos: [13]
# Palabra: 'las' aparece en los dicumentos: [8, 10, 14]
# Palabra: 'llena' aparece en los dicumentos: [16]
# Palabra: 'locales' aparece en los dicumentos: [14]
# Palabra: 'los' aparece en los dicumentos: [4, 7, 8, 8, 13, 16]
# Palabra: 'megadiverso,' aparece en los dicumentos: [1]
# Palabra: 'mercado' aparece en los dicumentos: [6]
# Palabra: 'montañas' aparece en los dicumentos: [1]
# Palabra: 'muchos' aparece en los dicumentos: [12]
# Palabra: 'mundo' aparece en los dicumentos: [2]
# Palabra: 'más' aparece en los dicumentos: [8]
# Palabra: 'nacionales.' aparece en los dicumentos: [16]
# Palabra: 'naturaleza.' aparece en los dicumentos: [15]
# Palabra: 'nocturna' aparece en los dicumentos: [10]
# Palabra: 'nublados.' aparece en los dicumentos: [9]
# Palabra: 'ofrece' aparece en los dicumentos: [8]
# Palabra: 'para' aparece en los dicumentos: [1, 9, 12]
# Palabra: 'paraíso' aparece en los dicumentos: [9]
# Palabra: 'país' aparece en los dicumentos: [1]
# Palabra: 'playas' aparece en los dicumentos: [5, 10]
# Palabra: 'playas,' aparece en los dicumentos: [1]
# Palabra: 'por' aparece en los dicumentos: [2, 3, 6]
# Palabra: 'páramos' aparece en los dicumentos: [13]
# Palabra: 'rafting' aparece en los dicumentos: [4]
# Palabra: 'región.' aparece en los dicumentos: [14]
# Palabra: 'se' aparece en los dicumentos: [16]
# Palabra: 'selvas' aparece en los dicumentos: [1]
# Palabra: 'senderos' aparece en los dicumentos: [11]
# Palabra: 'sorprende' aparece en los dicumentos: [10]
# Palabra: 'su' aparece en los dicumentos: [2, 6, 6, 7, 7, 10, 10, 10, 11]
# Palabra: 'surfistas' aparece en los dicumentos: [16]
# Palabra: 'todo' aparece en los dicumentos: [2]
# Palabra: 'tradicional.' aparece en los dicumentos: [7]
# Palabra: 'trekking' aparece en los dicumentos: [11]
# Palabra: 'turismo' aparece en los dicumentos: [1]
# Palabra: 'turistas' aparece en los dicumentos: [4, 7, 13, 14]
# Palabra: 'turquesa' aparece en los dicumentos: [11]
# Palabra: 'típica' aparece en los dicumentos: [14]
# Palabra: 'un' aparece en los dicumentos: [1, 3, 9]
# Palabra: 'una' aparece en los dicumentos: [8]
# Palabra: 'viajeros' aparece en los dicumentos: [16]
# Palabra: 'vibrante' aparece en los dicumentos: [6]
# Palabra: 'vida' aparece en los dicumentos: [10]
# Palabra: 'visitan' aparece en los dicumentos: [12]
# Palabra: 'visitantes' aparece en los dicumentos: [2, 15]
# Palabra: 'volcán' aparece en los dicumentos: [8]
# Palabra: 'y' aparece en los dicumentos: [1, 4, 5, 6, 7, 9, 10, 11, 12, 13, 14, 15, 16]
# Palabra: 'única.' aparece en los dicumentos: [2]
#
# Tabla comparativa de tiempos:
# Palabra         T. Lineal (s)   T. Índice (s)   Apariciones Lineal   Docs Índice
# --------------------------------------------------------------------------------
# quito           0.0009236336    0.0000042915    0                    0
# montañita       0.0005910397    0.0000023842    0                    0
# feriado         0.0004129410    0.0000014305    3                    1
# playas          0.0003314018    0.0000014305    3                    2
# aventura        0.0003304482    0.0000011921    1                    1
# galápagos       0.0003659725    0.0000011921    0                    0

# %% [markdown]
# ## Parte 4:
# ### Actividad
# 1. Modifica el índice para que ignore mayúsculas/minúsculas (por ejemplo, "Playa" y "playa" deben considerarse iguales).
# 2. Permite consultas de múltiples términos (ejemplo: buscar documentos que contengan "playa" y "turismo").
# 3. Calcula el _speedup_

# %%
import time
import pandas as pd

# --- Configuración ---
palabras_buscar = ["quito", "montañita", "feriado", "playas", "aventura", "galápagos"]
nombre_archivo = "01_corpus_turismo.txt"  # Tu archivo pequeño o grande

# --- Función búsqueda lineal (adaptada) ---
def find(palabra_buscar):
    inicio = time.time()
    try:
        with open(nombre_archivo, "r", encoding="utf-8") as archivo:
            lineas = archivo.readlines()

        documentos = []
        for numero_linea, linea in enumerate(lineas, start=1):
            if palabra_buscar.lower() in linea.lower():
                documentos.append(numero_linea)

        fin = time.time()
        tiempo = fin - inicio

        return {"documentos": documentos, "tiempo": tiempo}

    except FileNotFoundError:
        return {"documentos": [], "tiempo": 0}

# --- Crear índice invertido ---
def crear_indice_invertido():
    vocabulario = set()
    with open(nombre_archivo, 'r', encoding='utf-8') as archivo:
        lineas = archivo.readlines()

    for linea in lineas:
        palabras = linea.split()
        vocabulario.update(palabras)

    indice_invertido = {palabra.lower(): set() for palabra in vocabulario}

    for numero_linea, linea in enumerate(lineas, start=1):
        palabras = linea.split()
        for palabra in palabras:
            palabra = palabra.lower()
            indice_invertido[palabra].add(numero_linea)

    return indice_invertido

# --- Búsqueda en índice invertido (adaptada) ---
def buscar_en_indice(palabra, indice_invertido):
    palabra = palabra.strip().lower()
    inicio = time.time()

    documentos = indice_invertido.get(palabra, set())

    fin = time.time()
    tiempo = fin - inicio

    return {"documentos": documentos, "tiempo": tiempo}

# --- Búsqueda de múltiples términos ---
def buscar_multiples_terminos(palabras, indice_invertido):
    inicio = time.time()
    documentos_comunes = None
    
    for palabra in palabras:
        palabra = palabra.lower().strip()
        documentos = indice_invertido.get(palabra, set())

        if documentos_comunes is None:
            documentos_comunes = documentos
        else:
            documentos_comunes = documentos_comunes.intersection(documentos)

    documentos_comunes = documentos_comunes if documentos_comunes else set()
    fin = time.time()
    tiempo = fin - inicio

    return {"documentos": documentos_comunes, "tiempo": tiempo}

# --- Crear índice invertido una sola vez ---
indice_invertido = crear_indice_invertido()

# --- Lista para resultados individuales ---
resultados = []

# --- Búsqueda palabra por palabra ---
for palabra in palabras_buscar:
    # Búsqueda lineal
    resultado_lineal = find(palabra)
    # Búsqueda índice invertido
    resultado_indice = buscar_en_indice(palabra, indice_invertido)

    # Speedup (lineal/índice)
    if resultado_indice["tiempo"] > 0:
        speedup = resultado_lineal["tiempo"] / resultado_indice["tiempo"]
    else:
        speedup = float('inf')

    # Agregar resultados
    resultados.append({
        "Tipo de Búsqueda": "Individual",
        "Método": "Búsqueda lineal",
        "Palabra(s)": palabra,
        "Documentos encontrados": list(resultado_lineal["documentos"]),
        "Cantidad documentos": len(resultado_lineal["documentos"]),
        "Tiempo (segundos)": resultado_lineal["tiempo"],
        "Speedup": None  # Solo calculamos Speedup después
    })

    resultados.append({
        "Tipo de Búsqueda": "Individual",
        "Método": "Índice invertido",
        "Palabra(s)": palabra,
        "Documentos ": list(resultado_indice["documentos"]),
        "Cantidad documentos": len(resultado_indice["documentos"]),
        "Tiempo (segundos)": resultado_indice["tiempo"],
        "Speedup": speedup
    })

# --- Búsqueda de múltiples términos ---
palabras_multiples = ["playas", "turismo"]  

# Lineal para múltiples términos
inicio_lineal = time.time()
documentos_lineal = []
with open(nombre_archivo, "r", encoding="utf-8") as archivo:
    lineas = archivo.readlines()
    for numero_linea, linea in enumerate(lineas, start=1):
        if all(palabra.lower() in linea.lower() for palabra in palabras_multiples):
            documentos_lineal.append(numero_linea)
fin_lineal = time.time()
tiempo_lineal_multiples = fin_lineal - inicio_lineal
# Índice invertido para múltiples términos
resultado_multiples_indice = buscar_multiples_terminos(palabras_multiples, indice_invertido)
# Speedup de búsqueda múltiple
if resultado_multiples_indice["tiempo"] > 0:
    speedup_multiples = tiempo_lineal_multiples / resultado_multiples_indice["tiempo"]
else:
    speedup_multiples = float('inf')
# --- Agregar resultados de búsqueda múltiple ---
resultados.append({
    "Tipo de Búsqueda": "Múltiple",
    "Método": "Búsqueda lineal",
    "Palabra(s)": ", ".join(palabras_multiples),
    "Documentos encontrados": documentos_lineal,
    "Cantidad documentos": len(documentos_lineal),
    "Tiempo (segundos)": tiempo_lineal_multiples,
    "Speedup": None
})
resultados.append({
    "Tipo de Búsqueda": "Múltiple",
    "Método": "Índice invertido",
    "Palabra(s)": ", ".join(palabras_multiples),
    "Documentos encontrados": list(resultado_multiples_indice["documentos"]),
    "Cantidad documentos": len(resultado_multiples_indice["documentos"]),
    "Tiempo (segundos)": resultado_multiples_indice["tiempo"],
    "Speedup": speedup_multiples
})

# --- Crear tabla de resultados ---
df_resultados = pd.DataFrame(resultados)

# --- Mostrar tabla ---

print(df_resultados)
# Out:
#    Tipo de Búsqueda            Método       Palabra(s) Documentos encontrados  \
# 0        Individual   Búsqueda lineal            quito                    [3]
# 1        Individual  Índice invertido            quito                    [3]
# 2        Individual   Búsqueda lineal        montañita                [5, 16]
# 3        Individual  Índice invertido        montañita                   [16]
# 4        Individual   Búsqueda lineal          feriado           [12, 14, 16]
# 5        Individual  Índice invertido          feriado                   [14]
# 6        Individual   Búsqueda lineal           playas             [1, 5, 10]
# 7        Individual  Índice invertido           playas                [10, 5]
# 8        Individual   Búsqueda lineal         aventura                    [4]
# 9        Individual  Índice invertido         aventura                    [4]
# 10       Individual   Búsqueda lineal        galápagos                    [2]
# 11       Individual  Índice invertido        galápagos                    [2]
# 12         Múltiple   Búsqueda lineal  playas, turismo                    [1]
# 13         Múltiple  Índice invertido  playas, turismo                     []
#
#     Cantidad documentos  Tiempo (segundos)     Speedup
# 0                     1       1.823902e-04         NaN
# 1                     1       1.192093e-06  153.000000
# 2                     2       1.778603e-04         NaN
# 3                     1       9.536743e-07  186.500000
# 4                     3       1.182556e-04         NaN
# 5                     1       7.152557e-07  165.333333
# 6                     3       1.111031e-04         NaN
# 7                     2       7.152557e-07  155.333333
# 8                     1       1.451969e-04         NaN
# 9                     1       1.192093e-06  121.800000
# 10                    1       1.382828e-04         NaN
# 11                    1       9.536743e-07  145.000000
# 12                    1       3.783703e-04         NaN
# 13                    0       7.152557e-06   52.900000
