# %% [markdown]
# # Ejercicio 1: Introducción a Recuperación de Información
#
# ## Objetivo de la práctica
# - Entender el problema de **buscar información** en colecciones de texto.
# - Comprender por qué se necesita un **índice invertido** en recuperación de información.
# - Programar una primera solución manual y luego optimizarla con un índice.
# - Evaluar la mejora en tiempos de búsqueda cuando usamos estructuras adecuadas.

# %% [markdown]
# ## Parte 1: Búsqueda lineal en documentos
#
# ### Actividad
# 1. Se te proporcionará un conjunto de documentos de texto.
# 2. Escribe una función que:
#    - Lea todos los documentos.
#    - Busque una palabra ingresada por el usuario.
#    - Muestre en qué documentos aparece la palabra.

# %%
nombre_archivo = "01_corpus_turismo.txt"
palabra_buscar = "Ecuador"
def find(palabra_buscar):
    try:
        # Abrir y leer el archivo línea por línea
        with open(nombre_archivo, "r", encoding="utf-8") as archivo:
            lineas = archivo.readlines()

        # Lista para almacenar los resultados
        resultados = []
        conteo_total = 0

        # Buscar la palabra definida en cada línea y acumular resultados
        for numero_linea, linea in enumerate(lineas, start=1):
            apariciones_linea = linea.lower().count(palabra_buscar.lower())
            if apariciones_linea > 0:
                resultados.append({
                    "documento": numero_linea,
                    "apariciones": apariciones_linea
                })
                conteo_total += apariciones_linea

        # Imprimir los resultados en la terminal
        if resultados:
            print(f"La palabra '{palabra_buscar}' se encontró un total de {conteo_total} veces en el archivo.")
            print("Detalles de las apariciones:")
            for resultado in resultados:
                print(f"- Documento {resultado['documento']} (Apariciones: {resultado['apariciones']})")
        else:
            print(f"La palabra '{palabra_buscar}' no se encontró en el documento.")

        

    except FileNotFoundError:
        print(f"El archivo '{nombre_archivo}' no fue encontrado.")

# %% [markdown]
# ## Parte 2: Construcción de un índice invertido
#
# ### Actividad
# 1. Escribe un programa que:
#    - Recorra todos los documentos.
#    - Construya un **índice invertido**, es decir, un diccionario donde:
#      - Cada palabra clave apunta a una lista de documentos donde aparece.
#
# 2. Escribe una nueva función de búsqueda que:
#    - Consulte directamente el índice para encontrar los documentos relevantes.
#    - Sea mucho más rápida que la búsqueda lineal.

# %%
with open('01_corpus_turismo.txt', 'r', encoding='utf-8') as archivo:
    # Lee todas las líneas del archivo
    lineas = archivo.readlines()

# Usamos un conjunto (set) para almacenar las palabras sin duplicados
diccionario = set()

# Recorre cada línea del archivo
for linea in lineas:
    # Divide la línea en palabras usando el espacio como separador
    palabras_linea = linea.split()
    # Agrega las palabras de la línea al conjunto
    diccionario.update(palabras_linea)


# Nombre del archivo donde buscar
nombre_archivo = "01_corpus_turismo.txt"

# Iterar sobre cada palabra en el diccionario y usar find
for word in diccionario:
    resultado = find(word)
    if resultado:
        print(f"\nResultados para la palabra '{word}':")
        print(resultado["resultados"])
        print(f"Conteo total: {resultado['conteo_total']}")
# Out:
# La palabra 'cráter.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'la' se encontró un total de 22 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 2 (Apariciones: 2)
# - Documento 3 (Apariciones: 4)
# - Documento 5 (Apariciones: 2)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 2)
# - Documento 10 (Apariciones: 2)
# - Documento 11 (Apariciones: 2)
# - Documento 12 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 2)
# - Documento 15 (Apariciones: 2)
# La palabra 'como' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# - Documento 5 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# La palabra 'centro' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'con' se encontró un total de 8 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 3 (Apariciones: 1)
# - Documento 5 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# La palabra 'Cotopaxi' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'viajeros' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'cuenta' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'Patrimonio' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'Spondylus' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'se' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'López.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'colonial' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 7 (Apariciones: 1)
# La palabra 'a' se encontró un total de 180 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 11)
# - Documento 2 (Apariciones: 9)
# - Documento 3 (Apariciones: 10)
# - Documento 4 (Apariciones: 11)
# - Documento 5 (Apariciones: 11)
# - Documento 6 (Apariciones: 10)
# - Documento 7 (Apariciones: 11)
# - Documento 8 (Apariciones: 8)
# - Documento 9 (Apariciones: 10)
# - Documento 10 (Apariciones: 12)
# - Documento 11 (Apariciones: 8)
# - Documento 12 (Apariciones: 15)
# - Documento 13 (Apariciones: 18)
# - Documento 14 (Apariciones: 12)
# - Documento 15 (Apariciones: 15)
# - Documento 16 (Apariciones: 9)
# La palabra 'Parque' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'El' se encontró un total de 13 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 2)
# - Documento 2 (Apariciones: 1)
# - Documento 5 (Apariciones: 1)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 15 (Apariciones: 2)
# La palabra 'Laguna' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# La palabra 'impacta' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'excursionistas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'Las' se encontró un total de 5 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 2)
# - Documento 8 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'Malecón' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'bosques' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'durante' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'por' se encontró un total de 4 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 3 (Apariciones: 1)
# - Documento 4 (Apariciones: 1)
# - Documento 6 (Apariciones: 1)
# La palabra 'Galápagos' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'montañas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'Amazonía' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'paraíso' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'aventura' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'turistas' se encontró un total de 4 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'Pacífico.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'surfistas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'Ruta' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# - Documento 5 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'Montañita,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'Salinas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'famosas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'Humanidad' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'trekking' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'atraen' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'playas,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'y' se encontró un total de 19 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 2)
# - Documento 4 (Apariciones: 2)
# - Documento 5 (Apariciones: 3)
# - Documento 6 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 9 (Apariciones: 1)
# - Documento 10 (Apariciones: 3)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'atrae' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# La palabra 'impresionantes' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'un' se encontró un total de 9 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 2 (Apariciones: 1)
# - Documento 3 (Apariciones: 2)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# La palabra 'Cuenca' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 7 (Apariciones: 1)
# La palabra 'alrededor' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'conocido' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'Quito' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'mercado' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# La palabra 'Agua' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'el' se encontró un total de 13 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 2)
# - Documento 2 (Apariciones: 1)
# - Documento 5 (Apariciones: 1)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 15 (Apariciones: 2)
# La palabra 'nocturna' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'feriado' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'sorprende' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'una' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# La palabra 'ideales' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'deportes' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'feriado,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'megadiverso,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'región.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 14 (Apariciones: 1)
# La palabra 'Vilcabamba,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'mundo' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'vida' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# La palabra 'Los' se encontró un total de 7 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 8 (Apariciones: 2)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'ecológico.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'naturaleza.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'jóvenes' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'color' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'turismo' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'Ecuador' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'vibrante' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# La palabra 'ciudad' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'Baños' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'típica' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 14 (Apariciones: 1)
# La palabra 'fiestas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 14 (Apariciones: 1)
# La palabra 'turquesa' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'para' se encontró un total de 4 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 9 (Apariciones: 2)
# - Documento 12 (Apariciones: 1)
# La palabra 'nublados.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'canopy.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'del' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# La palabra 'senderos' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'interesados' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'feriados' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'las' se encontró un total de 5 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 2)
# - Documento 8 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'Guayaquil' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'todo' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'volcán' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'exploración' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'lagunas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'es' se encontró un total de 24 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 2)
# - Documento 2 (Apariciones: 1)
# - Documento 3 (Apariciones: 1)
# - Documento 4 (Apariciones: 1)
# - Documento 6 (Apariciones: 2)
# - Documento 7 (Apariciones: 1)
# - Documento 8 (Apariciones: 4)
# - Documento 9 (Apariciones: 3)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 14 (Apariciones: 2)
# - Documento 15 (Apariciones: 3)
# - Documento 16 (Apariciones: 2)
# La palabra 'altitud.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'nacionales.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'histórico' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'locales' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 14 (Apariciones: 1)
# La palabra 'cada' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'en' se encontró un total de 19 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 3 (Apariciones: 2)
# - Documento 4 (Apariciones: 2)
# - Documento 6 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 2)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 15 (Apariciones: 2)
# - Documento 16 (Apariciones: 2)
# La palabra 'conecta' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'Otavalo' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# La palabra 'conocer' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'Cajas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'de' se encontró un total de 28 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 2 (Apariciones: 1)
# - Documento 3 (Apariciones: 3)
# - Documento 4 (Apariciones: 4)
# - Documento 5 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 8 (Apariciones: 3)
# - Documento 9 (Apariciones: 2)
# - Documento 10 (Apariciones: 2)
# - Documento 11 (Apariciones: 4)
# - Documento 12 (Apariciones: 1)
# - Documento 14 (Apariciones: 3)
# - Documento 15 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'páramos' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'gran' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'caminatas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'Valle' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'llena' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 16 (Apariciones: 1)
# La palabra 'comunidades' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'biodiversidad' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'más' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'avistamiento' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'ecuatorianos' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'rafting' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'selvas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'Andes.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'su' se encontró un total de 10 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 6 (Apariciones: 2)
# - Documento 7 (Apariciones: 2)
# - Documento 10 (Apariciones: 3)
# - Documento 11 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'única.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'Islas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# La palabra 'visitan' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# La palabra 'arquitectura' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 7 (Apariciones: 1)
# La palabra 'Nacional' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'UNESCO.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'ascensiones' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'cultura' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# La palabra 'indígenas' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'visitantes' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 15 (Apariciones: 1)
# La palabra 'playas' se encontró un total de 3 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 5 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# La palabra '2000,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'aves' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'muchos' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'entre' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'disfrutan' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'artesanal.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# La palabra 'país' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# La palabra 'los' se encontró un total de 7 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 8 (Apariciones: 2)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)
# La palabra 'Puerto' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# La palabra 'indígena' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# - Documento 12 (Apariciones: 1)
# La palabra 'gastronomía' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 7 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# La palabra 'En' se encontró un total de 19 veces en el archivo.
# Detalles de las apariciones:
# - Documento 2 (Apariciones: 1)
# - Documento 3 (Apariciones: 2)
# - Documento 4 (Apariciones: 2)
# - Documento 6 (Apariciones: 1)
# - Documento 7 (Apariciones: 1)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 1)
# - Documento 10 (Apariciones: 1)
# - Documento 11 (Apariciones: 1)
# - Documento 12 (Apariciones: 2)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 1)
# - Documento 15 (Apariciones: 2)
# - Documento 16 (Apariciones: 2)
# La palabra 'deslumbra' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 7 (Apariciones: 1)
# La palabra 'cascadas.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 12 (Apariciones: 1)
# La palabra 'Longevidad,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'ofrece' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 8 (Apariciones: 1)
# La palabra 'bienestar' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 15 (Apariciones: 1)
# La palabra 'declarado' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 3 (Apariciones: 1)
# La palabra 'La' se encontró un total de 22 veces en el archivo.
# Detalles de las apariciones:
# - Documento 1 (Apariciones: 1)
# - Documento 2 (Apariciones: 2)
# - Documento 3 (Apariciones: 4)
# - Documento 5 (Apariciones: 2)
# - Documento 8 (Apariciones: 1)
# - Documento 9 (Apariciones: 2)
# - Documento 10 (Apariciones: 2)
# - Documento 11 (Apariciones: 2)
# - Documento 12 (Apariciones: 1)
# - Documento 13 (Apariciones: 1)
# - Documento 14 (Apariciones: 2)
# - Documento 15 (Apariciones: 2)
# La palabra 'cercanía' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 10 (Apariciones: 1)
# La palabra 'famoso' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 6 (Apariciones: 1)
# La palabra 'Quilotoa' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 11 (Apariciones: 1)
# La palabra 'Santa,' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 4 (Apariciones: 1)
# La palabra 'tradicional.' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 7 (Apariciones: 1)
# La palabra 'invita' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 13 (Apariciones: 1)
# La palabra 'Mindo' se encontró un total de 1 veces en el archivo.
# Detalles de las apariciones:
# - Documento 9 (Apariciones: 1)
# La palabra 'Montañita' se encontró un total de 2 veces en el archivo.
# Detalles de las apariciones:
# - Documento 5 (Apariciones: 1)
# - Documento 16 (Apariciones: 1)

# %% [markdown]
# ## Parte 3: Evaluación de tiempos de búsqueda
# ### Actividad
#
# 1. Realiza la búsqueda de varias palabras usando:
#       -  Corpus pequeño: 16 documentos (turismo en Ecuador).
#       -  Corpus grande: 500 documentos (versión ampliada).
# 2. Mide el tiempo de ejecución:
#       -  Para búsqueda lineal.
#       -  Para búsqueda usando índice invertido.
#       -  Grafica o presenta los resultados en una tabla comparativa.
#
# ### Ejemplo de palabras para buscar
# - quito
# - montañita
# - feriado
# - playas
# - aventura
# - galápagos

# %% [markdown]
# ## Parte 4:
# ### Actividad
# 1. Modifica el índice para que ignore mayúsculas/minúsculas (por ejemplo, "Playa" y "playa" deben considerarse iguales).
# 2. Permite consultas de múltiples términos (ejemplo: buscar documentos que contengan "playa" y "turismo").
# 3. Calcula el _speedup_
