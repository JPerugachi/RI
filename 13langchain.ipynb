# %% [markdown]
# # Ejercicio 13: LangChain
#
# LangChain es un _framework_ de código abierto diseñado para facilitar el desarrollo de aplicaciones que combinan modelos de lenguaje LLMs con datos, herramientas externas y memoria. Está especialmente pensado para construir aplicaciones complejas basadas en IA, como sistemas _Retrieval-Augmented Generation_, asistentes conversacionales inteligentes, agentes autónomos y sistemas con razonamiento compuesto.

# %% [markdown]
# ## Parte 1: Carga y preprocesamiento del corpus

# %%
import os
from dotenv import load_dotenv
import kaggle
import pandas as pd

# Cargar variables de entorno desde .env
load_dotenv()

os.environ["KAGGLE_USERNAME"] = os.getenv("KAGGLE_USERNAME")
os.environ["KAGGLE_KEY"] = os.getenv("KAGGLE_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# Descargar el dataset (si no existe)
dataset = "rajneesh231/lex-fridman-podcast-transcript"
path = "../data/13langchain"

kaggle.api.dataset_download_files(dataset, path=path, unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rajneesh231/lex-fridman-podcast-transcript

# %%
# Cargar el dataset CSV
file_path = os.path.join(path, "podcastdata_dataset.csv")  # ajusta nombre si difiere
df = pd.read_csv(file_path)
df
# Out:
#       id             guest                                              title  \
# 0      1       Max Tegmark                                           Life 3.0
# 1      2     Christof Koch                                      Consciousness
# 2      3     Steven Pinker                            AI in the Age of Reason
# 3      4     Yoshua Bengio                                      Deep Learning
# 4      5   Vladimir Vapnik                               Statistical Learning
# ..   ...               ...                                                ...
# 314  321      Ray Kurzweil    Singularity, Superintelligence, and Immortality
# 315  322  Rana el Kaliouby   Emotion AI, Social Robots, and Self-Driving Cars
# 316  323        Will Sasso  Comedy, MADtv, AI, Friendship, Madness, and Pr...
# 317  324   Daniel Negreanu                                              Poker
# 318  325     Michael Levin  Biology, Life, Aliens, Evolution, Embryogenesi...
#
#                                                   text
# 0    As part of MIT course 6S099, Artificial Genera...
# 1    As part of MIT course 6S099 on artificial gene...
# 2    You've studied the human mind, cognition, lang...
# 3    What difference between biological neural netw...
# 4    The following is a conversation with Vladimir ...
# ..                                                 ...
# 314  By the time he gets to 2045, we'll be able to ...
# 315  there's a broader question here, right? As we ...
# 316  Once this whole thing falls apart and we are c...
# 317  you could be the seventh best player in the wh...
# 318  turns out that if you train a planarian and th...
#
# [319 rows x 4 columns]

# %%
from langchain.schema import Document

# Convertir cada fila en un Document
documents = [
    Document(
        page_content=row["text"],
        metadata={"id": row["id"], "guest": row["guest"], "title": row["title"]},
    )
    for _, row in df.iterrows()
]

# %% [markdown]
# ## Parte 2: Segmentación y embeddings

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(documents)

# %%
#%pip install -U langchain-community
#%pip install -U langchain-huggingface
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.1-py3-none-any.whl.metadata (996 bytes)
# Collecting langchain-core<1.0.0,>=0.3.70 (from langchain-huggingface)
#   Downloading langchain_core-0.3.71-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tokenizers>=0.19.1 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-huggingface) (0.21.1)
# Collecting huggingface-hub>=0.33.4 (from langchain-huggingface)
#   Downloading huggingface_hub-0.33.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: langsmith>=0.3.45 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.7)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.14.0)
# Requirement already satisfied: packaging>=23.2 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in d:\septimo semestre\ri\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in d:\septimo semestre\ri\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.0.0)
# Requirement already satisfied: filelock in d:\septimo semestre\ri\.venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2025.5.1)
# Requirement already satisfied: requests in d:\septimo semestre\ri\.venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in d:\septimo semestre\ri\.venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\septimo semestre\ri\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in d:\septimo semestre\ri\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.9.0)
# Requirement already satisfied: certifi in d:\septimo semestre\ri\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in d:\septimo semestre\ri\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in d:\septimo semestre\ri\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\septimo semestre\ri\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\septimo semestre\ri\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\septimo semestre\ri\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\septimo semestre\ri\.venv\lib\site-packages (from requests->huggingface-hub>=0.33.4->langchain-huggingface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\septimo semestre\ri\.venv\lib\site-packages (from requests->huggingface-hub>=0.33.4->langchain-huggingface) (2.5.0)
# Requirement already satisfied: colorama in d:\septimo semestre\ri\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in d:\septimo semestre\ri\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.1)
# Downloading langchain_huggingface-0.3.1-py3-none-any.whl (27 kB)
# Downloading langchain_core-0.3.71-py3-none-any.whl (442 kB)
# Downloading huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
# Installing collected packages: huggingface-hub, langchain-core, langchain-huggingface
#
#   Attempting uninstall: huggingface-hub
#
#     Found existing installation: huggingface-hub 0.33.0
#
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#     Uninstalling huggingface-hub-0.33.0:
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#       Successfully uninstalled huggingface-hub-0.33.0
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/3 [huggingface-hub]
#     Found existing installation: langchain-core 0.3.69
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#     Uninstalling langchain-core-0.3.69:
#    ------------- -------------------------- 1/3 [langchain-core]
#       Successfully uninstalled langchain-core-0.3.69
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-huggingface]
#    -------------------------- ------------- 2/3 [langchain-huggingface]
#    -------------------------- ------------- 2/3 [langchain-huggingface]
#    ---------------------------------------- 3/3 [langchain-huggingface]
#
# Successfully installed huggingface-hub-0.33.4 langchain-core-0.3.71 langchain-huggingface-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip ins

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Crear embeddings con el nuevo paquete
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Extraer textos y crear el vectorstore
texts = [chunk.page_content for chunk in chunks]
vectorstore = FAISS.from_texts(texts, embeddings)

# Guardar localmente
vectorstore.save_local("index_13langchain")

# %% [markdown]
# ## Parte 3: Indexación en FAISS

# %%
vectorstore = FAISS.from_texts(texts, embeddings)
vectorstore.save_local("index_13langchain_02")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 vectorstore = FAISS.from_texts(texts, embeddings)
#       2 vectorstore.save_local("index_13langchain_02")
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:156, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     146 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     147     """Compute doc embeddings using a HuggingFace transformer model.
#     148
#     149     Args:
#    (...)    154
#     155     """
# --> 156     return self._embed(texts, self.encode_kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:131, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     129     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     130 else:
# --> 131     embeddings = self._client.encode(
#     132         texts,
#     133         show_progress_bar=self.show_progress,
#     134         **encode_kwargs,
#     135     )
#     137 if isinstance(embeddings, list):
#     138     msg = (
#     139         "Expected embeddings to be a Tensor or a numpy array, "
#     140         "got a list instead."
#     141     )
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:685, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     682 features.update(extra_features)
#     684 with torch.no_grad():
# --> 685     out_features = self.forward(features, **kwargs)
#     686     if self.device.type == "hpu":
#     687         out_features = copy.deepcopy(out_features)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:758, in SentenceTransformer.forward(self, input, **kwargs)
#     756     module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     757     module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 758     input = module(input, **module_kwargs)
#     759 return input
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\sentence_transformers\models\Transformer.py:442, in Transformer.forward(self, features, **kwargs)
#     435 """Returns token_embeddings, cls_token"""
#     436 trans_features = {
#     437     key: value
#     438     for key, value in features.items()
#     439     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     440 }
# --> 442 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     443 token_embeddings = outputs[0]
#     444 features["token_embeddings"] = token_embeddings
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:1016, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1009 # Prepare head mask if needed
#    1010 # 1.0 in head_mask indicate we keep the head
#    1011 # attention_probs has shape bsz x n_heads x N x N
#    1012 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1013 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1014 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1016 encoder_outputs = self.encoder(
#    1017     embedding_output,
#    1018     attention_mask=extended_attention_mask,
#    1019     head_mask=head_mask,
#    1020     encoder_hidden_states=encoder_hidden_states,
#    1021     encoder_attention_mask=encoder_extended_attention_mask,
#    1022     past_key_values=past_key_values,
#    1023     use_cache=use_cache,
#    1024     output_attentions=output_attentions,
#    1025     output_hidden_states=output_hidden_states,
#    1026     return_dict=return_dict,
#    1027 )
#    1028 sequence_output = encoder_outputs[0]
#    1029 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:662, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     651     layer_outputs = self._gradient_checkpointing_func(
#     652         layer_module.__call__,
#     653         hidden_states,
#    (...)    659         output_attentions,
#     660     )
#     661 else:
# --> 662     layer_outputs = layer_module(
#     663         hidden_states,
#     664         attention_mask,
#     665         layer_head_mask,
#     666         encoder_hidden_states,
#     667         encoder_attention_mask,
#     668         past_key_value,
#     669         output_attentions,
#     670     )
#     672 hidden_states = layer_outputs[0]
#     673 if use_cache:
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:594, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     591     cross_attn_present_key_value = cross_attention_outputs[-1]
#     592     present_key_value = present_key_value + cross_attn_present_key_value
# --> 594 layer_output = apply_chunking_to_forward(
#     595     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     596 )
#     597 outputs = (layer_output,) + outputs
#     599 # if decoder, return the attn key/values as the last output
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\transformers\pytorch_utils.py:253, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     250     # concatenate output at same dimension
#     251     return torch.cat(output_chunks, dim=chunk_dim)
# --> 253 return forward_fn(*input_tensors)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:607, in BertLayer.feed_forward_chunk(self, attention_output)
#     605 def feed_forward_chunk(self, attention_output):
#     606     intermediate_output = self.intermediate(attention_output)
# --> 607     layer_output = self.output(intermediate_output, attention_output)
#     608     return layer_output
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:519, in BertOutput.forward(self, hidden_states, input_tensor)
#     518 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 519     hidden_states = self.dense(hidden_states)
#     520     hidden_states = self.dropout(hidden_states)
#     521     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\SEPTIMO SEMESTRE\RI\.venv\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import google.generativeai as genai
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
for m in genai.list_models():
    print(m.name, m.supported_generation_methods)

# %% [markdown]
# ## Parte 4: Creación de la cadena de recuperación

# %%
# %pip install langchain-google-genai

# %%
from langchain.chains import RetrievalQA
from langchain_google_genai import ChatGoogleGenerativeAI

# Inicializar Gemini LLM
llm = ChatGoogleGenerativeAI(model="models/gemini-1.5-flash", temperature=0)

# Crear retriever desde tu índice vectorial (FAISS o Chroma)
retriever = vectorstore.as_retriever()

# Cadena de pregunta-respuesta
qa_chain = RetrievalQA.from_chain_type(llm, retriever=retriever)

# Ejecutar una pregunta
response = qa_chain.run("What is AGI Artificial General Intelligence?")
print(response)

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
Usa solo el siguiente contexto para responder a la pregunta.
Si la respuesta no está explícita en el contexto, responde exactamente:
"No encontré información suficiente en el corpus."

Contexto:
{context}

Pregunta: {question}
Respuesta:
"""
)

qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt}
)

result = qa_chain.invoke({"query": "¿Qué es AGI Artificial General Intelligence?"})
print(result["result"])

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=retriever,
    return_source_documents=True
)

result = qa_chain.invoke({"query": "¿Qué es AGI Artificial General Intelligence?"})
print(result["result"])
print(result["source_documents"])
